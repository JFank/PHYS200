# %%
In [1]: a = ramd(100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/jfank/PHYS200/<ipython-input-1-7007dea36c0f> in <module>()
# ----> 1 a = ramd(100)
#
# NameError: name 'ramd' is not defined

# %%
In [1]: a = rand(100)

# %%
ln [2]: plot(a)
# Out:
#   File "<ipython-input-3-1d2014a68eb4>", line 1
#     ln [2]: plot(a)
#           ^
# SyntaxError: invalid syntax

# %%
In [2]: plot(a)
